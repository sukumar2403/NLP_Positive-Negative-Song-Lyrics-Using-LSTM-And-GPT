# %% [markdown]
# # Data Gathering and Preparation

# %%
#importing all necessary packages
import apiKey
import lyricsgenius as lyrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sukum\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# !pip install lyricsgenius
# Out:
# Requirement already satisfied: lyricsgenius in c:\users\sukum\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in c:\users\sukum\anaconda3\lib\site-packages (from lyricsgenius) (4.12.3)
# Requirement already satisfied: requests>=2.20.0 in c:\users\sukum\anaconda3\lib\site-packages (from lyricsgenius) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sukum\anaconda3\lib\site-packages (from beautifulsoup4>=4.6.0->lyricsgenius) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sukum\anaconda3\lib\site-packages (from requests>=2.20.0->lyricsgenius) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sukum\anaconda3\lib\site-packages (from requests>=2.20.0->lyricsgenius) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sukum\anaconda3\lib\site-packages (from requests>=2.20.0->lyricsgenius) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sukum\anaconda3\lib\site-packages (from requests>=2.20.0->lyricsgenius) (2024.8.30)

# %%
#To access the client key
keyapi = apiKey.key

# %%
#The lyrics are scarped from Genius using their built-in api, which is initialized here
geniusapi = lyrics.Genius(keyapi)

# %% [markdown]
# A function to scrape the lyrics using the genius api. We select 15 artists who have atleast 50 songs in order to get a varied dataset(read report for details).

# %%
def scrapeLyrics(api, artist_list):
    """
    This function scrapes the lyrics using Genius API
    
    input:
    api - Genius API client key
    artist_list - List containing names of artists or groups
    
    output:
    Pandas DataFrame containing 2 columns - Artists and Lyrics
    """
    lyrics = []
    artist_l = []
    
    for artist in artist_list:
        success = False
        while(not success):
            try:
                songs = api.search_artist(artist, max_songs = 50)
                success = True
            except:
                continue
            
        for song in songs.songs:
            if(song.lyrics):
                lyrics.append(song.lyrics)
                artist_l.append(artist)
    
    return pd.DataFrame(list(zip(artist_l, lyrics)), columns = ['Artist', 'Lyrics'])

# %%
artist_names = ['Metallica', 'Ariana-grande', 'Coldplay', 'Billie-eilish', 'Beyonce', 'Charlie-puth','Ed-sheeran', 'Dua-lipa', 'Radiohead', 'Dream-theater', 'Stevie-wonder', 'Sting', 'Taylor-swift', 'Maroon-5', 'Justin-bieber']

# %%
data = scrapeLyrics(geniusapi, artist_names)
# Out:
# Searching for songs by Metallica...
#
# Song 1: "One"
# Song 2: "Nothing Else Matters"
# Song 3: "Enter Sandman"
# Song 4: "Master of Puppets"
# Song 5: "The Unforgiven"
# Song 6: "Fade to Black"
# Song 7: "For Whom the Bell Tolls"
# Song 8: "Creeping Death"
# Song 9: "Sad but True"
# Song 10: "Ride the Lightning"
# Song 11: "Fuel"
# Song 12: "...And Justice for All"
# Song 13: "Welcome Home (Sanitarium)"
# Song 14: "Wherever I May Roam"
# Song 15: "Blackened"
# Song 16: "Battery"
# Song 17: "The Unforgiven II"
# Song 18: "The Four Horsemen"
# Song 19: "Whiplash"
# Song 20: "Whiskey in the Jar"
# Song 21: "Dyers Eve"
# Song 22: "Seek & Destroy"
# Song 23: "The Unforgiven III"
# Song 24: "Eye of the Beholder"
# Song 25: "To Live Is to Die"
# Song 26: "Turn the Page"
# Song 27: "Disposable Heroes"
# Song 28: "The Day That Never Comes"
# Song 29: "Harvester of Sorrow"
# Song 30: "St. Anger"
# Song 31: "The Thing That Should Not Be"
# Song 32: "King Nothing"
# Song 33: "Atlas, Rise!"
# Song 34: "72 Seasons"
# Song 35: "Don’t Tread on Me"
# Song 36: "Orion"
# Song 37: "Am I Evil?"
# Song 38: "Mama Said"
# Song 39: "Until It Sleeps"
# Song 40: "Leper Messiah"
# Song 41: "No Leaf Clover"
# Song 42: "Lux Æterna"
# Song 43: "Damage, Inc."
# Song 44: "Moth Into Flame"
# Song 45: "Motorbreath"
# Song 46: "Hardwired"
# Song 47: "Fight Fire with Fire"
# Song 48: "Hero of the Day"
# Song 49: "The Shortest Straw"
# Song 50: "Spit Out the Bone"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Ariana-grande...
#
# Changing artist name to 'Ariana Grande'
# Song 1: "thank u, next"
# Searching for songs by Ariana-grande...
#
# Changing artist name to 'Ariana Grande'
# Song 1: "thank u, next"
# Song 2: "7 rings"
# Song 3: "​God is a woman"
# Song 4: "Side To Side"
# Song 5: "​no tears left to cry"
# Searching for songs by Ariana-grande...
#
# Changing artist name to 'Ariana Grande'
# Song 1: "thank u, next"
# Song 2: "7 rings"
# Song 3: "​God is a woman"
# Song 4: "Side To Side"
# Song 5: "​no tears left to cry"
# Song 6: "34+35"
# Song 7: "break up with your girlfriend, i’m bored"
# Song 8: "​breathin"
# Song 9: "positions"
# Song 10: "yes, and?"
# Song 11: "One Last Time"
# Song 12: "imagine"
# Song 13: "pov"
# Song 14: "needy"
# Song 15: "ghostin"
# Song 16: "in my head"
# Song 17: "pete davidson"
# Song 18: "Let Me Love You"
# Song 19: "​sweetener"
# Song 20: "Dangerous Woman"
# Song 21: "​R.E.M."
# Song 22: "we can’t be friends (wait for your love)"
# Song 23: "NASA"
# Song 24: "bloodline"
# Song 25: "Into You"
# Song 26: "fantasize*"
# Song 27: "​goodnight n go"
# Song 28: "fake smile"
# Song 29: "the light is coming"
# Song 30: "34+35 (Remix)"
# Song 31: "bad idea"
# Song 32: "​better off"
# Song 33: "Problem"
# Song 34: "make up"
# Song 35: "get well soon"
# Song 36: "The Way"
# Song 37: "eternal sunshine"
# Song 38: "everytime"
# Song 39: "motive"
# Song 40: "Moonlight"
# Song 41: "nasty"
# Song 42: "Focus"
# Song 43: "​safety net"
# Song 44: "just like magic"
# Song 45: "the boy is mine"
# Song 46: "Everyday"
# Song 47: "Santa Tell Me"
# Song 48: "my hair"
# Song 49: "Be Alright"
# Song 50: "raindrops (an angel cried)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Coldplay...
#
# Song 1: "Viva La Vida"
# Song 2: "The Scientist"
# Song 3: "Yellow"
# Song 4: "Fix You"
# Song 5: "Hymn for the Weekend"
# Song 6: "Sparks"
# Song 7: "A Sky Full of Stars"
# Song 8: "Adventure of a Lifetime"
# Song 9: "Everglow"
# Song 10: "Clocks"
# Song 11: "Paradise"
# Song 12: "Magic"
# Song 13: "Orphans"
# Song 14: "Daddy"
# Song 15: "Higher Power"
# Song 16: "Everyday Life"
# Song 17: "​feelslikeimfallinginlove"
# Song 18: "Trouble"
# Song 19: "In My Place"
# Song 20: "Up&Up"
# Song 21: "Violet Hill"
# Song 22: "Arabesque"
# Song 23: "Shiver"
# Song 24: "Warning Sign"
# Song 25: "Hypnotised"
# Song 26: "Don’t Panic"
# Song 27: "Green Eyes"
# Song 28: "Fly On"
# Song 29: "Strawberry Swing"
# Song 30: "Champion of the World"
# Song 31: "A Rush of Blood to the Head"
# Song 32: "All I Can Think About Is You"
# Song 33: "Coloratura"
# Song 34: "Every Teardrop Is A Waterfall"
# Song 35: "Always in My Head"
# Song 36: "Ink"
# Song 37: "O"
# Song 38: "Charlie Brown"
# Song 39: "God Put a Smile Upon Your Face"
# Song 40: "Speed of Sound"
# Song 41: "Church"
# Song 42: "Amsterdam"
# Song 43: "Midnight"
# Song 44: "Death and All His Friends"
# Song 45: "Trouble in Town"
# Song 46: "True Love"
# Song 47: "Talk"
# Song 48: "Politik"
# Song 49: "Christmas Lights"
# Song 50: "A Head Full of Dreams"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Billie-eilish...
#
# Changing artist name to 'Billie Eilish'
# Song 1: "​when the party’s over"
# Song 2: "Happier Than Ever"
# Song 3: "bad guy"
# Song 4: "​everything i wanted"
# Song 5: "​idontwannabeyouanymore"
# Song 6: "​bury a friend"
# Song 7: "​i love you"
# Song 8: "Your Power"
# Song 9: "No Time To Die"
# Song 10: "​wish you were gay"
# Song 11: "​​ocean eyes"
# Song 12: "BIRDS OF A FEATHER"
# Song 13: "Therefore I Am"
# Song 14: "LUNCH"
# Song 15: "my future"
# Song 16: "CHIHIRO"
# Song 17: "​bellyache"
# Song 18: "WILDFLOWER"
# Song 19: "​all the good girls go to hell"
# Song 20: "xanny"
# Song 21: "​you should see me in a crown"
# Song 22: "What Was I Made For?"
# Song 23: "​ilomilo"
# Song 24: "listen before i go"
# Song 25: "COPYCAT"
# Song 26: "​my strange addiction"
# Song 27: "​watch"
# Song 28: "​hostage"
# Song 29: "BLUE"
# Song 30: "L’AMOUR DE MA VIE"
# Song 31: "THE GREATEST"
# Song 32: "​my boy"
# Song 33: "SKINNY"
# Song 34: "Six Feet Under"
# Song 35: "NDA"
# Song 36: "Bored"
# Song 37: "THE DINER"
# Song 38: "8"
# Song 39: "​bitches broken hearts"
# Song 40: "​​come out and play"
# Song 41: "Male Fantasy"
# Song 42: "6.18.18"
# Song 43: "​goodbye"
# Song 44: "​​party favor"
# Song 45: "Billie Bossa Nova"
# Song 46: "BITTERSUITE"
# Song 47: "TV"
# Song 48: "The 30th"
# Song 49: "Halley’s Comet"
# Song 50: "The End of the World"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Beyonce...
#
# Changing artist name to 'Beyoncé'
# Song 1: "Drunk in Love"
# Song 2: "Formation"
# Song 3: "Partition"
# Song 4: "Halo"
# Song 5: "If I Were a Boy"
# Song 6: "Mine"
# Song 7: "Hold Up"
# Song 8: "Flawless (Remix)"
# Song 9: "Sorry"
# Song 10: "Pray You Catch Me"
# Song 11: "All Night"
# Song 12: "***Flawless"
# Song 13: "Freedom"
# Song 14: "Don’t Hurt Yourself"
# Song 15: "Blow"
# Song 16: "Listen"
# Song 17: "Rocket"
# Song 18: "Sandcastles"
# Song 19: "Pretty Hurts"
# Song 20: "6 Inch"
# Song 21: "7/11"
# Song 22: "Love Drought"
# Song 23: "Drunk in Love (Remix)"
# Song 24: "Irreplaceable"
# Song 25: "XO"
# Song 26: "Haunted"
# Song 27: "Crazy in Love"
# Song 28: "Daddy Lessons"
# Song 29: "Countdown"
# Song 30: "Heaven"
# Song 31: "HEATED"
# Song 32: "JOLENE"
# Song 33: "Jealous"
# Song 34: "TEXAS HOLD ’EM"
# Song 35: "BLACK PARADE"
# Song 36: "BREAK MY SOUL"
# Song 37: "Bow Down / I Been On"
# Song 38: "MOOD 4 EVA"
# Song 39: "Love on Top"
# Song 40: "Forward"
# Song 41: "Upgrade U"
# Song 42: "Blue"
# Song 43: "DAUGHTER"
# Song 44: "Lemonade Film (Script)"
# Song 45: "16 CARRIAGES"
# Song 46: "Single Ladies (Put a Ring on It)"
# Song 47: "Me, Myself and I"
# Song 48: "ALIEN SUPERSTAR"
# Song 49: "CUFF IT"
# Song 50: "Grown Woman"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Charlie-puth...
#
# Changing artist name to 'Charlie Puth'
# Song 1: "Attention"
# Song 2: "We Don’t Talk Anymore"
# Searching for songs by Charlie-puth...
#
# Changing artist name to 'Charlie Puth'
# Song 1: "Attention"
# Song 2: "We Don’t Talk Anymore"
# Song 3: "How Long"
# Song 4: "One Call Away"
# Song 5: "Marvin Gaye"
# Song 6: "Done for Me"
# Song 7: "The Way I Am"
# Song 8: "Light Switch"
# Song 9: "Dangerously"
# Song 10: "See You Again (Original Version)"
# Song 11: "That’s Hilarious"
# Song 12: "Cheating on You"
# Song 13: "If You Leave Me Now"
# Song 14: "Betty Boop"
# Song 15: "Patient"
# Song 16: "I Warned Myself"
# Song 17: "BOY"
# Song 18: "I Don’t Think That I Like Her"
# Song 19: "Change"
# Song 20: "Mother"
# Song 21: "LA Girls"
# Song 22: "That’s Not How This Works"
# Song 23: "Suffer"
# Song 24: "River"
# Song 25: "Loser"
# Song 26: "Slow It Down"
# Song 27: "Girlfriend"
# Song 28: "Somebody Told Me"
# Song 29: "Empty Cups"
# Song 30: "Smells Like Me"
# Song 31: "Through It All"
# Song 32: "Hero"
# Song 33: "Some Type of Love"
# Song 34: "Kiss Me"
# Song 35: "Does It Feel"
# Song 36: "One Call Away (Remix)"
# Song 37: "My Gospel"
# Song 38: "Charlie Be Quiet!"
# Song 39: "I Don’t Wanna Know"
# Song 40: "Look at Me Now"
# Song 41: "Losing My Mind"
# Song 42: "Left Right Left"
# Song 43: "As You Are"
# Song 44: "There’s A First Time For Everything"
# Song 45: "Tears On My Piano"
# Song 46: "Up All Night"
# Song 47: "Lipstick"
# Song 48: "I Won’t Tell a Soul"
# Song 49: "No More Drama"
# Song 50: "Then There’s You"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Ed-sheeran...
#
# Changing artist name to 'Ed Sheeran'
# Searching for songs by Ed-sheeran...
#
# Changing artist name to 'Ed Sheeran'
# Song 1: "Shape of You"
# Song 2: "Perfect"
# Song 3: "Photograph"
# Song 4: "Castle On The Hill"
# Searching for songs by Ed-sheeran...
#
# Changing artist name to 'Ed Sheeran'
# Song 1: "Shape of You"
# Song 2: "Perfect"
# Song 3: "Photograph"
# Song 4: "Castle On The Hill"
# Song 5: "Thinking Out Loud"
# Song 6: "Supermarket Flowers"
# Song 7: "Happier"
# Song 8: "Galway Girl"
# Song 9: "The A Team"
# Song 10: "Dive"
# Song 11: "Don’t"
# Song 12: "Bad Habits"
# Song 13: "South of the Border"
# Song 14: "I See Fire"
# Song 15: "Beautiful People"
# Song 16: "Remember the Name"
# Song 17: "Eraser"
# Song 18: "Afterglow"
# Song 19: "New Man"
# Song 20: "How Would You Feel (Paean)"
# Song 21: "Nancy Mulligan"
# Song 22: "Barcelona"
# Song 23: "You Need Me, I Don’t Need You (Live at The Live Room)"
# Song 24: "Shivers"
# Song 25: "Give Me Love"
# Song 26: "You Need Me, I Don’t Need You"
# Song 27: "Lego House"
# Song 28: "Visiting Hours"
# Song 29: "Kiss Me"
# Song 30: "Tenerife Sea"
# Song 31: "What Do I Know?"
# Song 32: "Cross Me"
# Song 33: "Save Myself"
# Song 34: "Shape of You (Stormzy Remix)"
# Song 35: "Hearts Don’t Break Around Here"
# Song 36: "Bibia Be Ye Ye"
# Song 37: "I’m a Mess"
# Song 38: "Sing"
# Song 39: "Take Me Back To London"
# Song 40: "One"
# Song 41: "Bloodstream"
# Song 42: "Afire Love"
# Song 43: "U.N.I."
# Song 44: "Eyes Closed"
# Song 45: "Take It Back"
# Song 46: "Take Me Back To London (Remix)"
# Song 47: "Best Part of Me"
# Song 48: "The Joker And The Queen"
# Song 49: "Small Bump"
# Song 50: "Nina"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Dua-lipa...
#
# Changing artist name to 'Dua Lipa'
# Song 1: "New Rules"
# Song 2: "Don’t Start Now"
# Song 3: "Levitating"
# Song 4: "IDGAF"
# Song 5: "Blow Your Mind (Mwah)"
# Song 6: "Break My Heart"
# Song 7: "Be the One"
# Song 8: "Levitating (Remix)"
# Song 9: "Physical"
# Song 10: "We’re Good"
# Song 11: "Homesick"
# Song 12: "Love Again"
# Song 13: "Hotter Than Hell"
# Song 14: "Boys Will Be Boys"
# Song 15: "Houdini"
# Song 16: "Thinking ’Bout You"
# Song 17: "Pretty Please"
# Song 18: "Good in Bed"
# Song 19: "Future Nostalgia"
# Song 20: "Genesis"
# Song 21: "Lost in Your Light"
# Song 22: "Hallucinate"
# Song 23: "Dance The Night"
# Song 24: "Cool"
# Song 25: "Training Season"
# Song 26: "Swan Song"
# Song 27: "Illusion"
# Song 28: "Last Dance"
# Song 29: "New Love"
# Song 30: "No Goodbyes"
# Song 31: "Want To"
# Song 32: "Garden"
# Song 33: "These Walls"
# Song 34: "Bang Bang"
# Song 35: "Bad Together"
# Song 36: "Training Season (Extended)"
# Song 37: "Begging"
# Song 38: "Room for 2"
# Song 39: "Happy For You"
# Song 40: "End Of An Era"
# Song 41: "Dreams"
# Song 42: "French Exit"
# Song 43: "Falling Forever"
# Song 44: "Maria"
# Song 45: "Whatcha Doing"
# Song 46: "That Kind of Woman"
# Song 47: "Anything For Love"
# Song 48: "If It Ain’t Me"
# Song 49: "I’m Not the Only One"
# Song 50: "Levitating (The Blessed Madonna Remix)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Radiohead...
#
# Song 1: "Creep"
# Song 2: "Karma Police"
# Song 3: "No Surprises"
# Song 4: "Exit Music (For A Film)"
# Song 5: "Paranoid Android"
# Song 6: "Fake Plastic Trees"
# Song 7: "True Love Waits"
# Song 8: "Weird Fishes/Arpeggi"
# Song 9: "All I Need"
# Song 10: "How to Disappear Completely"
# Song 11: "Let Down"
# Song 12: "High and Dry"
# Song 13: "Daydreaming"
# Song 14: "Jigsaw Falling into Place"
# Song 15: "Nude"
# Song 16: "Motion Picture Soundtrack"
# Song 17: "Everything in Its Right Place"
# Song 18: "Idioteque"
# Song 19: "Reckoner"
# Song 20: "Fitter Happier"
# Song 21: "Burn the Witch"
# Song 22: "Airbag"
# Song 23: "Street Spirit (Fade Out)"
# Song 24: "Decks Dark"
# Song 25: "Present Tense"
# Song 26: "Climbing Up the Walls"
# Song 27: "Just"
# Song 28: "Videotape"
# Song 29: "House of Cards"
# Song 30: "2 + 2 = 5"
# Song 31: "Subterranean Homesick Alien"
# Song 32: "My Iron Lung"
# Song 33: "Identikit"
# Song 34: "Kid A"
# Song 35: "15 Step"
# Song 36: "Lucky"
# Song 37: "Pyramid Song"
# Song 38: "(Nice Dream)"
# Song 39: "Bodysnatchers"
# Song 40: "Ful Stop"
# Song 41: "There, There"
# Song 42: "Optimistic"
# Song 43: "Black Star"
# Song 44: "The Tourist"
# Song 45: "A Wolf at the Door"
# Song 46: "The Bends"
# Song 47: "The Numbers"
# Song 48: "I Promise"
# Song 49: "The National Anthem"
# Song 50: "Glass Eyes"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Dream-theater...
#
# Changing artist name to 'Dream Theater'
# Song 1: "Octavarium"
# Song 2: "Pull Me Under"
# Song 3: "Scene Eight: The Spirit Carries On"
# Song 4: "Scene Nine: Finally Free"
# Song 5: "Panic Attack"
# Song 6: "Metropolis - Part I: “The Miracle and the Sleeper”"
# Song 7: "A Change of Seasons"
# Song 8: "Another Day"
# Song 9: "Scene Six: Home"
# Song 10: "Scene Two: II. Strange Déjà Vu"
# Song 11: "The Count of Tuscany"
# Song 12: "Six Degrees of Inner Turbulence"
# Song 13: "Space-Dye Vest"
# Song 14: "Barstool Warrior"
# Song 15: "In the Name of God"
# Song 16: "As I Am"
# Song 17: "Hollow Years"
# Song 18: "Untethered Angel"
# Song 19: "Scene Three: II. Fatal Tragedy"
# Song 20: "Scene Five: Through Her Eyes"
# Song 21: "Scene Four: Beyond This Life"
# Song 22: "Take the Time"
# Song 23: "At Wit’s End"
# Song 24: "Repentance"
# Song 25: "Learning to Live"
# Song 26: "Scene One: Regression"
# Song 27: "Honor Thy Father"
# Song 28: "The Root of All Evil"
# Song 29: "Wither"
# Song 30: "The Glass Prison"
# Song 31: "The Best of Times"
# Song 32: "Surrounded"
# Song 33: "Finally Free"
# Song 34: "The Alien"
# Song 35: "This Dying Soul"
# Song 36: "Fall into the Light"
# Song 37: "The Spirit Carries On"
# Song 38: "Scene Three: I. Through My Words"
# Song 39: "A Nightmare to Remember"
# Song 40: "In the Presence of Enemies - Part II"
# Song 41: "6:00"
# Song 42: "Paralyzed"
# Song 43: "Scene Seven: II. One Last Time"
# Song 44: "Pale Blue Dot"
# Song 45: "The Twelve-Step Suite"
# Song 46: "Under a Glass Moon"
# Song 47: "Endless Sacrifice"
# Song 48: "Wait for Sleep"
# Song 49: "Scene Two: I. Overture 1928"
# Song 50: "You Not Me"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Stevie-wonder...
#
# Changing artist name to 'Stevie Wonder'
# Song 1: "As"
# Song 2: "Superstition"
# Song 3: "Isn’t She Lovely"
# Song 4: "I Wish"
# Song 5: "I Just Called to Say I Love You"
# Song 6: "Sir Duke"
# Song 7: "Don’t You Worry ’Bout a Thing"
# Song 8: "Higher Ground"
# Song 9: "Signed, Sealed, Delivered I’m Yours"
# Song 10: "Happy Birthday"
# Song 11: "Living for the City"
# Song 12: "Faith"
# Song 13: "Overjoyed"
# Song 14: "Master Blaster (Jammin’)"
# Song 15: "Knocks Me Off My Feet"
# Song 16: "My Cherie Amour"
# Song 17: "Ribbon in the Sky"
# Song 18: "Part-Time Lover"
# Song 19: "Do I Do"
# Song 20: "All I Do"
# Song 21: "Love’s in Need of Love Today"
# Song 22: "For Once in My Life"
# Song 23: "Pastime Paradise"
# Song 24: "You Are the Sunshine of My Life"
# Song 25: "Black Man"
# Song 26: "Lately"
# Song 27: "Talkbox Medley (Close to You / Never Can Say Goodbye)"
# Song 28: "They Won’t Go When I Go"
# Song 29: "Rocket Love"
# Song 30: "That Girl"
# Song 31: "Ngiculela - Es Una Historia - I Am Singing"
# Song 32: "Too High"
# Song 33: "Another Star"
# Song 34: "Visions"
# Song 35: "Never Dreamed You’d Leave in Summer"
# Song 36: "I Was Made to Love Her"
# Song 37: "If It’s Magic"
# Song 38: "You and I (We Can Conquer the World)"
# Song 39: "All in Love Is Fair"
# Song 40: "Summer Soft"
# Song 41: "Someday at Christmas"
# Song 42: "He’s Misstra Know-It-All"
# Song 43: "Golden Lady"
# Song 44: "You Haven’t Done Nothin’"
# Song 45: "Superwoman (Where Were You When I Needed You)"
# Song 46: "Village Ghetto Land"
# Song 47: "Joy Inside My Tears"
# Song 48: "Ordinary Pain"
# Song 49: "Saturn"
# Song 50: "I Believe (When I Fall in Love It Will Be Forever)"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Sting...
#
# Song 1: "Shape of My Heart"
# Song 2: "Englishman in New York"
# Song 3: "Desert Rose"
# Song 4: "Fragile"
# Song 5: "Fields of Gold"
# Song 6: "Russians"
# Song 7: "What Could Have Been"
# Song 8: "It’s probably me"
# Song 9: "If I Ever Lose My Faith in You"
# Song 10: "Mad About You"
# Song 11: "Soul Cake"
# Song 12: "A Thousand Years"
# Song 13: "Seven Days"
# Song 14: "Brand New Day"
# Song 15: "If You Love Somebody Set Them Free"
# Song 16: "All This Time"
# Song 17: "Fortress Around Your Heart"
# Song 18: "Moon Over Bourbon Street"
# Song 19: "They Dance Alone"
# Song 20: "Roxanne"
# Song 21: "When We Dance"
# Song 22: "La Belle Dame Sans Regrets"
# Song 23: "The Last Ship"
# Song 24: "I Can’t Stop Thinking About You"
# Song 25: "Until"
# Song 26: "Rushing Water"
# Song 27: "Children’s Crusade"
# Song 28: "Love Is the Seventh Wave"
# Song 29: "If It’s Love"
# Song 30: "Why Should I Cry for You?"
# Song 31: "Windmills of Your Mind"
# Song 32: "We’ll Be Together"
# Song 33: "My Funny Friend and Me"
# Song 34: "Saint Augustine in Hell"
# Song 35: "I Hung My Head"
# Song 36: "We Work the Black Seam"
# Song 37: "Every Breath You Take"
# Song 38: "Be Still My Beating Heart"
# Song 39: "Little Wing"
# Song 40: "The Empty Chair"
# Song 41: "Sister Moon"
# Song 42: "I’m So Happy I Can’t Stop Crying"
# Song 43: "The Hounds of Winter"
# Song 44: "Ghost Story"
# Song 45: "The Lazarus Heart"
# Song 46: "All Would Envy"
# Song 47: "The Soul Cages"
# Song 48: "Stolen Car (Take Me Dancing)"
# Song 49: "The Book of My Life"
# Song 50: "I Love Her But She Loves Someone Else"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Taylor-swift...
#
# Changing artist name to 'Taylor Swift'
# Song 1: "All Too Well (10 Minute Version) (Taylor’s Version) [From The Vault]"
# Song 2: "All Too Well (10 Minute Version) (Taylor’s Version) [Live Acoustic]"
# Song 3: "Fortnight"
# Song 4: "cardigan"
# Song 5: "So Long, London"
# Song 6: "The Tortured Poets Department"
# Song 7: "exile"
# Song 8: "Lover"
# Song 9: "Down Bad"
# Song 10: "loml"
# Song 11: "But Daddy I Love Him"
# Song 12: "Is It Over Now? (Taylor’s Version) [From The Vault]"
# Song 13: "the 1"
# Song 14: "​thanK you aIMee"
# Song 15: "august"
# Song 16: "Cruel Summer"
# Song 17: "I Can Do It With a Broken Heart"
# Song 18: "​tolerate it"
# Song 19: "The Smallest Man Who Ever Lived"
# Song 20: "Guilty as Sin?"
# Song 21: "​champagne problems"
# Song 22: "Look What You Made Me Do"
# Song 23: "Anti-Hero"
# Song 24: "So High School"
# Song 25: "betty"
# Song 26: "Who’s Afraid of Little Old Me?"
# Song 27: "The Alchemy"
# Song 28: "Blank Space"
# Song 29: "Style"
# Song 30: "My Boy Only Breaks His Favorite Toys"
# Song 31: "You’re Losing Me (From The Vault)"
# Song 32: "my tears ricochet"
# Song 33: "...Ready for It?"
# Song 34: "“Slut!” (Taylor’s Version) [From The Vault]"
# Song 35: "Florida!!!"
# Song 36: "We Are Never Ever Getting Back Together"
# Song 37: "End Game"
# Song 38: "​willow"
# Song 39: "You Need To Calm Down"
# Song 40: "You’re On Your Own, Kid"
# Song 41: "Fresh Out The Slammer"
# Song 42: "Love Story"
# Song 43: "Maroon"
# Song 44: "invisible string"
# Song 45: "ME!"
# Song 46: "All Too Well"
# Song 47: "Karma"
# Song 48: "seven"
# Song 49: "the last great american dynasty"
# Song 50: "Clara Bow"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Maroon-5...
#
# Changing artist name to 'Maroon 5'
# Song 1: "Girls Like You (Remix)"
# Song 2: "Memories"
# Song 3: "What Lovers Do"
# Song 4: "Sugar"
# Song 5: "Payphone"
# Song 6: "Girls Like You"
# Song 7: "One More Night"
# Song 8: "Don’t Wanna Know"
# Song 9: "Animals"
# Song 10: "She Will Be Loved"
# Song 11: "Cold"
# Song 12: "Maps"
# Song 13: "This Love"
# Song 14: "Wait"
# Song 15: "Sunday Morning"
# Song 16: "Moves Like Jagger"
# Song 17: "Nobody’s Love"
# Song 18: "Daylight"
# Song 19: "Whiskey"
# Song 20: "Misery"
# Song 21: "Lost"
# Song 22: "Harder to Breathe"
# Song 23: "Won’t Go Home Without You"
# Song 24: "Love Somebody"
# Song 25: "Lips on You"
# Song 26: "This Summer’s Gonna Hurt Like a Motherfucker"
# Song 27: "Makes Me Wonder"
# Song 28: "Payphone (Radio Version)"
# Song 29: "Help Me Out"
# Song 30: "Wake Up Call"
# Song 31: "Who I Am"
# Song 32: "Beautiful Goodbye"
# Song 33: "Sad"
# Song 34: "Lucky Strike"
# Song 35: "Wait (Remix)"
# Song 36: "It Was Always You"
# Song 37: "Best 4 U"
# Song 38: "Nothing Lasts Forever"
# Song 39: "Feelings"
# Song 40: "Middle Ground"
# Song 41: "Closure"
# Song 42: "Unkiss Me"
# Song 43: "Animals (Remix)"
# Song 44: "My Heart Is Open"
# Song 45: "Sugar (Remix)"
# Song 46: "Can’t Leave You Alone"
# Song 47: "The Sun"
# Song 48: "Secret"
# Song 49: "Bet My Heart"
# Song 50: "Just a Feeling"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.
# Searching for songs by Justin-bieber...
#
# Changing artist name to 'Justin Bieber'
# Song 1: "Love Yourself"
# Song 2: "Baby"
# Song 3: "Sorry"
# Song 4: "Yummy"
# Song 5: "What Do You Mean?"
# Song 6: "As Long As You Love Me"
# Song 7: "Peaches"
# Song 8: "Holy"
# Song 9: "Intentions"
# Song 10: "Beauty and a Beat"
# Song 11: "Confident"
# Song 12: "Mistletoe"
# Song 13: "Ghost"
# Song 14: "Anyone"
# Song 15: "I’ll Show You"
# Song 16: "Mark My Words"
# Song 17: "Purpose"
# Song 18: "Boyfriend"
# Song 19: "Company"
# Song 20: "That Should Be Me"
# Song 21: "All That Matters"
# Song 22: "No Sense"
# Song 23: "Never Say Never"
# Song 24: "The Feeling"
# Song 25: "No Pressure"
# Song 26: "Hold On"
# Song 27: "Off My Face"
# Song 28: "Maria"
# Song 29: "Forever"
# Song 30: "Hold Tight"
# Song 31: "Come Around Me"
# Song 32: "Unstable"
# Song 33: "Heartbreaker"
# Song 34: "2 Much"
# Song 35: "Life Is Worth Living"
# Song 36: "As I Am"
# Song 37: "Get Me"
# Song 38: "Right Here"
# Song 39: "Habitual"
# Song 40: "Changes"
# Song 41: "Nothing Like Us"
# Song 42: "Love Me"
# Song 43: "Boyfriend (Remix)"
# Song 44: "Loved By You"
# Song 45: "We Are"
# Song 46: "Been You"
# Song 47: "All Around Me"
# Song 48: "Hard 2 Face Reality"
# Song 49: "E.T.A."
# Song 50: "Deserve You"
#
# Reached user-specified song limit (50).
# Done. Found 50 songs.

# %% [markdown]
# The data from Genius is converted to a dataframe using pandas.

# %%
data.to_csv('Complete.csv', encoding='utf-8', index = False)

# %%
data.head()
# Out:
#       Artist                                             Lyrics
# 0  Metallica  147 ContributorsTranslationsFrançaisPortuguêsD...
# 1  Metallica  114 ContributorsTranslationsPolskiDeutschPortu...
# 2  Metallica  138 ContributorsTranslationsPortuguêsNederland...
# 3  Metallica  152 ContributorsTranslationsPortuguêsEspañolDe...
# 4  Metallica  94 ContributorsTranslationsDeutschPortuguêsNed...

# %% [markdown]
# The data is cleaned like 'verse/intro/chorus/bridge/instrumental' are removed, multiple sentence endings are removed etc.

# %%
def cleanlyrics(dataframe):
    """
    Method to remove special characters in the lyrics column
    
    input:
    dataframe - Data containing artists and Song Lyrics
    
    output:
    dataframe - Cleaned Lyrics
    """
    dataframe['Lyrics'] = dataframe['Lyrics'].str.lower()
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"\d", "", regex=True)  # Remove digits
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"intro|instrumental|chorus|verse|bridge|outro", "", regex=True)  # Remove unwanted words
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"\[", "", regex=True)  # Escape [
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"\]", "", regex=True)  # Escape ]
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"  ", " ", regex=True)  # Remove extra spaces
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"\t", "", regex=True)  # Remove tabs
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(r"[^\w\d'\s]+", "", regex=True)  # Remove non-alphanumeric characters
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace(":", "", regex=True)  # Remove colons
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace("\n \n \n", "\n", regex=True)  # Normalize newlines
    dataframe['Lyrics'] = dataframe['Lyrics'].str.replace("\n", " \n ", regex=True)  # Add space around newlines
    dataframe['Lyrics'] = dataframe['Lyrics'].str.strip()  # Strip leading/trailing spaces

    return dataframe

cleanlyrics(data)
# Out:
#             Artist                                             Lyrics
# 0        Metallica  contributorstranslationsfrançaisportuguêsdeuts...
# 1        Metallica  contributorstranslationspolskideutschportuguês...
# 2        Metallica  contributorstranslationsportuguêsnederlandsdeu...
# 3        Metallica  contributorstranslationsportuguêsespañoldeutsc...
# 4        Metallica  contributorstranslationsdeutschportuguêsnederl...
# ..             ...                                                ...
# 745  Justin-bieber  contributorstranslationsespañolbeen you lyrics...
# 746  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
# 747  Justin-bieber  contributorshard face reality lyrics justin bi...
# 748  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
# 749  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
#
# [750 rows x 2 columns]

# %%
data.head(5)
# Out:
#       Artist                                             Lyrics
# 0  Metallica  contributorstranslationsfrançaisportuguêsdeuts...
# 1  Metallica  contributorstranslationspolskideutschportuguês...
# 2  Metallica  contributorstranslationsportuguêsnederlandsdeu...
# 3  Metallica  contributorstranslationsportuguêsespañoldeutsc...
# 4  Metallica  contributorstranslationsdeutschportuguêsnederl...

# %% [markdown]
# The data is now sent to a sentiment analyzer that classifies the lyrics on the basis of positive/negative sentiment. Astonishingly, we had more positive lyrics than negative ones. True numbers are specified in the dataset section of the report.

# %%
def getsentiment(dataframe):
    """
    Method to get sentiment analysis for the Lyrics in the dataframe
    
    input:
    Dataframe - data containing details regarding artists and song lyrics
    
    output:
    Dataframe - data containing details regarding artist, song lyrics and corresponding lyrics sentiments
    
    """
    sentlist = []
    #Initializing the sentiment analyzer
    vader = SentimentIntensityAnalyzer()
    
    #Looping through each row, and based on the Lyrics,
    #the sentiment analyzer scores the lyrics for amount of negative and positive
    for row in range(len(dataframe)):
        sentiment = vader.polarity_scores(dataframe.loc[row, "Lyrics"])
        if sentiment['neg'] > sentiment['pos']:
            sentlist.append(0)
        else:
            sentlist.append(1)
    
    dataframe['Sentiment'] = sentlist


getsentiment(data)

# %%
data.groupby(data.Sentiment).nunique()
# Out:
#            Artist  Lyrics
# Sentiment
# 0              15     263
# 1              15     487

# %%
sortedsent = data.groupby(data.Sentiment)

# %% [markdown]
# The split data is grouped into two different datasets- positive lyrics dataset and negative lyrics dataset which is used as sample input for our lyric generator.

# %%
#Sorting based on sentiment column value
sortedsentpos = sortedsent.get_group(1)
sortedsentneg = sortedsent.get_group(0)

# %%
#Sorted positive sentiments
sortedsentpos
# Out:
#             Artist                                             Lyrics  \
# 2        Metallica  contributorstranslationsportuguêsnederlandsdeu...
# 3        Metallica  contributorstranslationsportuguêsespañoldeutsc...
# 8        Metallica  contributorstranslationsportuguêsnederlandssad...
# 11       Metallica  contributorsand justice for all lyrics  \n hal...
# 13       Metallica  contributorstranslationsportuguêsnederlandswhe...
# ..             ...                                                ...
# 742  Justin-bieber  contributorsboyfriend remix lyrics asher roth ...
# 743  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
# 746  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
# 748  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
# 749  Justin-bieber  contributorstranslationstürkçeespañolportuguês...
#
#      Sentiment
# 2            1
# 3            1
# 8            1
# 11           1
# 13           1
# ..         ...
# 742          1
# 743          1
# 746          1
# 748          1
# 749          1
#
# [487 rows x 3 columns]

# %%
#Sorted negative sentiments
sortedsentneg
# Out:
#             Artist                                             Lyrics  \
# 0        Metallica  contributorstranslationsfrançaisportuguêsdeuts...
# 1        Metallica  contributorstranslationspolskideutschportuguês...
# 4        Metallica  contributorstranslationsdeutschportuguêsnederl...
# 5        Metallica  contributorstranslationstürkçedeutschfade to b...
# 6        Metallica  contributorstranslationsdeutschfor whom the be...
# ..             ...                                                ...
# 727  Justin-bieber  contributorsmaria lyrics matt lauer  justin bi...
# 728  Justin-bieber  contributorstranslationstürkçeespañolforever l...
# 744  Justin-bieber  contributorstranslationsespañolwe are lyrics j...
# 745  Justin-bieber  contributorstranslationsespañolbeen you lyrics...
# 747  Justin-bieber  contributorshard face reality lyrics justin bi...
#
#      Sentiment
# 0            0
# 1            0
# 4            0
# 5            0
# 6            0
# ..         ...
# 727          0
# 728          0
# 744          0
# 745          0
# 747          0
#
# [263 rows x 3 columns]

# %%
#Saving the positive and negative sentiment files separately
sortedsentpos.to_csv('positive.csv', encoding='utf-8', index = False)
sortedsentneg.to_csv('negative.csv', encoding='utf-8', index = False)
